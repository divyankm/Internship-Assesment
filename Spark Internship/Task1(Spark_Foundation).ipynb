# %% [markdown]
# GRIP : The Spark Foundation ( Data Science and Business Analytics Intern )
#
# Name: Divyank Mahalle
#
# Task 1: Prediction the Percentage of a Student's Based on the No. of Study Hours using Supervised ML
#
# Supervised machine learningis a type of machine learning in which the machine is fed the training data which is labelled. Supervised machine learning is further categorized into regression and classification.
#
# Linear regression is probably the simplest approach for statistical learning.
#
# In this task we have to predict the percentage score of a student based on the number of hours studied.The task has two variable where the feature is the no, of hours studied and the target value is the percentage score.This can be solved by using Machine Learning(Supervised Linear Regression).

# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('https://raw.githubusercontent.com/AdiPersonalWorks/Random/master/student_scores%20-%20student_scores.csv')
df
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
df.shape
# Out:
# (25, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   25 non-null     float64
#  1   Scores  25 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 528.0 bytes

# %%
df.nunique()
# Out:
# Hours     23
# Scores    23
# dtype: int64

# %%
df.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
sns.histplot(data=df,x='Hours')   #Number of students studying for number of hours

# %% [markdown]
# #We are observing linear relationship in between Number of Hours student studying and scores.Higher the number of hours of study, higher will be the score.

# %%
sns.regplot(data=df,x='Hours',y='Scores')

# %% [markdown]
# ##Splitting data into Dependent and Independent Variable

# %%
X = df[['Hours']].values   #X is dependent variable

y = df[['Scores']].values  #y is independent variable

# %% [markdown]
# Performing Linerar Regression Model.
#
# Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y, test_size=0.2, random_state=0)

# %% [markdown]
# ##Training the Simple Linear Regression model on the Training set

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ##Predicting the Test set results

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([[16.88414476],
#        [33.73226078],
#        [75.357018  ],
#        [26.79480124],
#        [60.49103328]])

# %% [markdown]
# ## Visualising the Training set results

# %%
plt.scatter(X_train,y_train ,color='g',marker='*')
plt.plot(X_test,regressor.predict(X_test),color='r')
plt.title('Training Dataset')
plt.xlabel('Number of Hours')
plt.ylabel('Scores')
plt.grid()
plt.show()

# %% [markdown]
# ##Visualising the Test set results

# %%
plt.scatter(X_test, y_test, color = 'red',marker='*')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('Hours Vs Scores (Test set)')
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.grid()
plt.show()

# %% [markdown]
# What will be predicted score if a student studies for 9.25 hrs/ day?
#
# #Student Score will be 95.35 according to Lin Regression Model.

# %%
lin_reg.predict([[9.5]])
# Out:
# array([[95.35380562]])

# %% [markdown]
# #Thank you,The Spark Foundation
